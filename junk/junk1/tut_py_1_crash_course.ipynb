# %% [markdown]
# # crash course
#
# ```
# In the vastness of space, you define
# A beauty that's beyond compare
# A sight that makes us all stop and stareTwinkling lights in the dark night sky
# Guiding us through life, as we try
# To find our way, to reach our dreams
# ```

# %%
# Part 1: Python Basics for ML Crash Course

# print("1 Hello world") # octothorpe or hashtag

# using , to print series of stmts 
print("2 Hello world. Today its raining")
print("3 Hello world.", "Today its raining")
print("4 Hello world.", "Today its raining", "It is going to be humid today.", "Good luck")


print("""In the vastness of space, you define
A beauty that's beyond compare
A sight that makes us all stop and stareTwinkling lights in the dark night sky
Guiding us through life, as we try
To find our way, to reach our dreams""")


print("x")
print(x) # gives error because x is variable and not define. So lets define the var.

# 1. Python Syntax & Data Types: int, string, float, bool, complex,
x = 10           # integer
y = 3.14         # float
name = "Alice"   # string
is_ready = True  # boolean
z = None         # NoneType


print("The variable x:",x)
print(f"The variable x: {x}")
print(f"The type is : {type(x)}")

print("The variable y:",y)
print(f"The variable y: {y}")
print(f"The type is : {type(y)}")

print("The variable name:",name)
print(f"The variable name: {name}")
print(f"The type is : {type(name)}")

print("The variable is_ready:", is_ready)
print(f"The variable is_ready: {is_ready}")
print(f"The type is : {type(is_ready)}")

print("The variable z: ",z)
print(f"The variable z: {z}")

#multiline strings
msg = """Hello students.
Hope you enjoy this class.
Good luck
"""
print(msg)

# Type conversion
a = int(3.7)
b = float("2.5")
c = str(100)
print(f"Converted values: {a}, {b}, {c}")

# 2. Control Structures
if x > 5:
    print("x is greater than 5")
    print("CONGRATULATION")
elif x == 5:
    print("x is 5")
    print(" Well, I am happy for x")
else:
    print("x is less than 5")
    print("x is not happy")


print("Hello world")
print("Hello world")
print("Hello world")
for i in range(3):
  print("Hello world")
  
  
for i in range(3):
    print("I am trapped inside a for loop. When would I get out?.")
    print(f"Loop iterator: {i}")

print("YEA...Finally I am out")

count = 0
while count < 3:
    print("I am trapped inside a while loop. Somebody help me.")
    print(f"Count is: {count}")
    count += 1

# 3. Data Structures
# List
my_list = [7, 2, 1, 4, 1, 4]
print(f"First element: {my_list[0]}")

# Tuple
my_tuple = (7, 2, 1, 4, 1, 4)
print(f"Tuple: {my_tuple}")

# Set
my_set = {7, 2, 1, 4, 1, 4}  # duplicates removed
print(f"Set: {my_set}")

# Dictionary
data = {"name": "Alice", 
        "age": 25
       }
print(f"Name: {data['name']}")

# List comprehension
squares = [x**2 for x in range(5)]
print(f"Squares: {squares}")

# 4. Functions
def greet(name):
    print("OK, Now I am inside a function.")
    return f"Hello, {name}!"

res = greet("Bob")
print(res)

def add(a,b):
    res = a + b
    return res
    
ans = add(3,4)
print(f"Function add: {ans)}")


# Lambda function
add = lambda a, b: a + b
print(f"Lambda add: {add(3, 4)}")

# 5. Error Handling
try:
    result = 10 / 0
except ZeroDivisionError:
    print("You can't divide by zero!")
# Out:
#   Cell In[2], line 49
#     print("x is greater than 5"whileprint("CONGRATULATION")
#          ^
# SyntaxError: '(' was never closed
